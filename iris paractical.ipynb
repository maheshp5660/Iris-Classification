# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('iris.csv' , header=None, names=['Sep Len','Sep Wid','Pet Len', 'Pet Wid', 'Class'])

# %%
df
# Out:
#      Sep Len  Sep Wid  Pet Len  Pet Wid           Class
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        4.6      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    Sep Len  Sep Wid  Pet Len  Pet Wid        Class
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
df.tail()
# Out:
#      Sep Len  Sep Wid  Pet Len  Pet Wid           Class
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Sep Len  150 non-null    float64
#  1   Sep Wid  150 non-null    float64
#  2   Pet Len  150 non-null    float64
#  3   Pet Wid  150 non-null    float64
#  4   Class    150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#           Sep Len     Sep Wid     Pet Len     Pet Wid
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
#df.iloc[:2,0:2].value_counts()

# %%
df.dtypes
# Out:
# Sep Len    float64
# Sep Wid    float64
# Pet Len    float64
# Pet Wid    float64
# Class       object
# dtype: object

# %%
df.head()
# Out:
#    Sep Len  Sep Wid  Pet Len  Pet Wid        Class
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
df['Class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Class, dtype: int64

# %%
df.Class.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.isnull()
# Out:
#      Sep Len  Sep Wid  Pet Len  Pet Wid  Class
# 0      False    False    False    False  False
# 1      False    False    False    False  False
# 2      False    False    False    False  False
# 3      False    False    False    False  False
# 4      False    False    False    False  False
# ..       ...      ...      ...      ...    ...
# 145    False    False    False    False  False
# 146    False    False    False    False  False
# 147    False    False    False    False  False
# 148    False    False    False    False  False
# 149    False    False    False    False  False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Sep Len    0
# Sep Wid    0
# Pet Len    0
# Pet Wid    0
# Class      0
# dtype: int64

# %%
df = df.replace({'Iris-setosa':0 , 'Iris-virginica':1 , 'Iris-versicolor':2})

# %%
df.head()
# Out:
#    Sep Len  Sep Wid  Pet Len  Pet Wid  Class
# 0      5.1      3.5      1.4      0.2      0
# 1      4.9      3.0      1.4      0.2      0
# 2      4.7      3.2      1.3      0.2      0
# 3      4.6      3.1      1.5      0.2      0
# 4      5.0      3.6      1.4      0.2      0

# %%
df.tail()
# Out:
#      Sep Len  Sep Wid  Pet Len  Pet Wid  Class
# 145      6.7      3.0      5.2      2.3      1
# 146      6.3      2.5      5.0      1.9      1
# 147      6.5      3.0      5.2      2.0      1
# 148      6.2      3.4      5.4      2.3      1
# 149      5.9      3.0      5.1      1.8      1

# %%
import seaborn as sns

# %%
sns.distplot(df)
# Out:
# /tmp/ipykernel_762/107776459.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.boxplot(df)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x=df['Class'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=(30, 35))
df.hist(bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'Sep Len'}>,
#         <AxesSubplot:title={'center':'Sep Wid'}>],
#        [<AxesSubplot:title={'center':'Pet Len'}>,
#         <AxesSubplot:title={'center':'Pet Wid'}>],
#        [<AxesSubplot:title={'center':'Class'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## UNIVARIATE ANALYSIS #

# %%
df.loc[df['Class']==0]
# Out:
#     Sep Len  Sep Wid  Pet Len  Pet Wid  Class
# 0       5.1      3.5      1.4      0.2      0
# 1       4.9      3.0      1.4      0.2      0
# 2       4.7      3.2      1.3      0.2      0
# 3       4.6      3.1      1.5      0.2      0
# 4       5.0      3.6      1.4      0.2      0
# 5       5.4      3.9      1.7      0.4      0
# 6       4.6      3.4      1.4      0.3      0
# 7       5.0      3.4      1.5      0.2      0
# 8       4.4      2.9      1.4      0.2      0
# 9       4.9      3.1      1.5      0.1      0
# 10      5.4      3.7      1.5      0.2      0
# 11      4.8      3.4      1.6      0.2      0
# 12      4.8      3.0      1.4      0.1      0
# 13      4.3      3.0      1.1      0.1      0
# 14      5.8      4.0      1.2      0.2      0
# 15      5.7      4.4      1.5      0.4      0
# 16      5.4      3.9      1.3      0.4      0
# 17      5.1      3.5      1.4      0.3      0
# 18      5.7      3.8      1.7      0.3      0
# ...

# %%
df.loc[df['Class']==2]
# Out:
#     Sep Len  Sep Wid  Pet Len  Pet Wid  Class
# 50      7.0      3.2      4.7      1.4      2
# 51      6.4      3.2      4.5      1.5      2
# 52      6.9      3.1      4.9      1.5      2
# 53      5.5      2.3      4.0      1.3      2
# 54      6.5      2.8      4.6      1.5      2
# 55      5.7      2.8      4.5      1.3      2
# 56      6.3      3.3      4.7      1.6      2
# 57      4.9      2.4      3.3      1.0      2
# 58      6.6      2.9      4.6      1.3      2
# 59      5.2      2.7      3.9      1.4      2
# 60      5.0      2.0      3.5      1.0      2
# 61      5.9      3.0      4.2      1.5      2
# 62      6.0      2.2      4.0      1.0      2
# 63      6.1      2.9      4.7      1.4      2
# 64      5.6      2.9      3.6      1.3      2
# 65      6.7      3.1      4.4      1.4      2
# 66      5.6      3.0      4.5      1.5      2
# 67      5.8      2.7      4.1      1.0      2
# 68      6.2      2.2      4.5      1.5      2
# ...

# %%
df.dtypes
# Out:
# Sep Len    float64
# Sep Wid    float64
# Pet Len    float64
# Pet Wid    float64
# Class        int64
# dtype: object

# %%
import seaborn as sns

# %%
sns.FacetGrid(df,hue="Class", height=5).map(plt.scatter,"Sep Len", "Pet Len").add_legend();
plt.show();

# %%
sns.FacetGrid(df,hue="Class", height=5).map(sns.distplot,"Sep Len").add_legend();
plt.show();
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /opt/conda/lib/python3.8/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.pairplot(df,hue="Class",size=5)
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.corr()
# Out:
#           Sep Len   Sep Wid   Pet Len   Pet Wid     Class
# Sep Len  1.000000 -0.109369  0.871754  0.817954  0.331175
# Sep Wid -0.109369  1.000000 -0.420516 -0.356544 -0.576396
# Pet Len  0.871754 -0.420516  1.000000  0.962757  0.501129
# Pet Wid  0.817954 -0.356544  0.962757  1.000000  0.424931
# Class    0.331175 -0.576396  0.501129  0.424931  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# x = np.array(df.iloc[:,:-1])
# y = np.array(df.iloc[:,-1])

# %% [markdown]
# #### SPILT DATASET INTO TRAIN AND TEST

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.25 , random_state=42)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
x_train.shape
# Out:
# (112, 4)

# %%
x_test.shape
# Out:
# (38, 4)

# %%
y_train.shape
# Out:
# (112,)

# %%
y_test.shape
# Out:
# (38,)

# %% [markdown]
# ### Feature Sclaing

# %%
from sklearn.preprocessing  import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
type(y_train)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Build Model ####

# %% [markdown]
# ### LOGISTICS REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(multi_class="multinomial")
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)

# %%
sum([pred==test for pred,test in zip(y_pred,y_test)])/len(y_pred)
# Out:
# 0.9736842105263158

# %%
sum([pred==test for pred,test in zip(y_pred,y_test)])
# Out:
# 37

# %%
## 
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9736842105263158

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9736842105263158
